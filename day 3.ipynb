# %%
for i in range(3):  # Outer loop
    for j in range(2):  # Inner loop
        for k in range(3):  
            for l in range(2):
                for m in range(3): 
                    for n in range(2):
                        for o in range(3):
                            for p in range(2):
                                for q in range(3):  
                                    for r in range(2):
                                        print(f"i={i}, j={j},k={k}, l={l},m={m}, n={n}, o={o},p={p}, q={q}, r={r}")
# Out:
# i=0, j=0,k=0, l=0,m=0, n=0, o=0,p=0, q=0, r=0
# i=0, j=0,k=0, l=0,m=0, n=0, o=0,p=0, q=0, r=1
# i=0, j=0,k=0, l=0,m=0, n=0, o=0,p=0, q=1, r=0
# i=0, j=0,k=0, l=0,m=0, n=0, o=0,p=0, q=1, r=1
# i=0, j=0,k=0, l=0,m=0, n=0, o=0,p=0, q=2, r=0
# i=0, j=0,k=0, l=0,m=0, n=0, o=0,p=0, q=2, r=1
# i=0, j=0,k=0, l=0,m=0, n=0, o=0,p=1, q=0, r=0
# i=0, j=0,k=0, l=0,m=0, n=0, o=0,p=1, q=0, r=1
# i=0, j=0,k=0, l=0,m=0, n=0, o=0,p=1, q=1, r=0
# i=0, j=0,k=0, l=0,m=0, n=0, o=0,p=1, q=1, r=1
# i=0, j=0,k=0, l=0,m=0, n=0, o=0,p=1, q=2, r=0
# i=0, j=0,k=0, l=0,m=0, n=0, o=0,p=1, q=2, r=1
# i=0, j=0,k=0, l=0,m=0, n=0, o=1,p=0, q=0, r=0
# i=0, j=0,k=0, l=0,m=0, n=0, o=1,p=0, q=0, r=1
# i=0, j=0,k=0, l=0,m=0, n=0, o=1,p=0, q=1, r=0
# i=0, j=0,k=0, l=0,m=0, n=0, o=1,p=0, q=1, r=1
# i=0, j=0,k=0, l=0,m=0, n=0, o=1,p=0, q=2, r=0
# i=0, j=0,k=0, l=0,m=0, n=0, o=1,p=0, q=2, r=1
# i=0, j=0,k=0, l=0,m=0, n=0, o=1,p=1, q=0, r=0
# i=0, j=0,k=0, l=0,m=0, n=0, o=1,p=1, q=0, r=1
# ...
